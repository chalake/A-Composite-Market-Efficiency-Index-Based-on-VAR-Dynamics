# %%
from pathlib import Path
from src.futures.synthetic import build_synthetic_contract_data

target_months = {
    "2405": [3, 4],
    "2407": [5, 6],
    "2409": [7, 8],
    "2411": [9, 10],
    "2501": [11, 12],
    "2503": [1, 2],
}

data_dir = Path("../data/raw")

synthetic_df = build_synthetic_contract_data(
    data_dir=data_dir,
    target_months=target_months
)

synthetic_df.head()
