# %%
from src.var.rolling import rolling_var_analysis

df = load_and_prepare_data(...)
df_diff = df.diff().dropna()

fevd, lags, irf_lags = rolling_var_analysis(
    data=df_diff,
    window_size=60,
    max_lag=15
)
