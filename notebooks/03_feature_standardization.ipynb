# %%
zscore_shifted_features = scale_features(
    df,
    positive_features,
    negative_features,
    method="zscore",
    shift=True,
    index_col="window",
)

# %%
minmax_features = scale_features(
    df,
    positive_features,
    negative_features,
    method="minmax",
    index_col="window",
)
