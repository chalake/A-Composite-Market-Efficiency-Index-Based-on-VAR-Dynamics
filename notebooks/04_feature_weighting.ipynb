# %%
import pandas as pd
from src.indexing.weights import compute_entropy_weights

# Load shifted & standardized features
df = pd.read_excel(
    "data/zscore_standardized_features_shifted.xlsx"
)

weights = compute_entropy_weights(
    df=df,
    index_col="window"
)

weights.to_excel(
    "data/rolling_var_and_market_features_weights.xlsx"
)
